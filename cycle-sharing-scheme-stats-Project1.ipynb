# 57043                                  2nd Ave & Vine St          DPD-01
# 57044                              9th Ave N & Mercer St          SLU-07
# 57045                             Westlake Ave & 6th Ave           CH-07
# 57046  Burke-Gilman Trail / NE Blakeley St & 24th Ave NE           UW-06
# 57047                                1st Ave & Marion St          SLU-19
# 57048                     Republican St & Westlake Ave N          SLU-01
# 57049             Cal Anderson Park / 11th Ave & Pine St           CH-05
# 57050                              9th Ave N & Mercer St          SLU-15
# 57051                                 7th Ave & Union St          SLU-18
# 57052                         REI / Yale Ave N & John St          SLU-16
# 57053                              9th Ave N & Mercer St           BT-03
# 57054                      PATH / 9th Ave & Westlake Ave           BT-03
# 57055                                  Pine St & 9th Ave           CH-02
# 57056                                  2nd Ave & Pine St          SLU-01
# 57057                     Republican St & Westlake Ave N           CH-01
# 57058                    Pier 69 / Alaskan Way & Clay St           PS-05
# 57059                     Republican St & Westlake Ave N           BT-01
# 57060  Occidental Park / Occidental Ave S & S Washing...           FH-04
# 57061                                                NaN             NaN
#
#       to_station_id                usertype  gender  birthyear
# 0             PS-04                  Member    Male     1960.0
# 1             PS-04                  Member    Male     1970.0
# 2             PS-04                  Member  Female     1988.0
# 3             PS-04                  Member  Female     1977.0
# 4             PS-04                  Member    Male     1971.0
# 5             PS-04                  Member    Male     1974.0
# 6             PS-05                  Member    Male     1978.0
# 7             PS-05                  Member    Male     1983.0
# 8             PS-05                  Member  Female     1974.0
# 9             PS-05                  Member    Male     1958.0
# 10            PS-05                  Member  Female     1983.0
# 11            PS-05                  Member    Male     1982.0
# 12            PS-05                  Member    Male     1984.0
# 13            PS-05                  Member    Male     1955.0
# 14            PS-05                  Member    Male     1953.0
# 15            PS-05                  Member  Female     1958.0
# 16            PS-05                  Member    Male     1959.0
# 17            PS-05                  Member    Male     1950.0
# 18           CBD-07                  Member  Female     1976.0
# 19           CBD-05                  Member    Male     1986.0
# 20           CBD-05                  Member    Male     1953.0
# 21           CBD-05                  Member    Male     1986.0
# 22           CBD-07                  Member    Male     1967.0
# 23           CBD-05                  Member  Female     1986.0
# 24           CBD-05                  Member  Female     1987.0
# 25           CBD-05                  Member  Female     1987.0
# 26           CBD-05                  Member    Male     1974.0
# 27           CBD-05                  Member    Male     1967.0
# 28           CBD-05                  Member  Female     1983.0
# 29           CBD-06                  Member    Male     1970.0
# ...             ...                     ...     ...        ...
# 57032         BT-03                  Member    Male     1981.0
# 57033         CH-07  Short-Term Pass Holder     NaN        NaN
# 57034        CBD-07  Short-Term Pass Holder     NaN        NaN
# 57035        SLU-07                  Member    Male     1991.0
# 57036        SLU-19                  Member  Female     1983.0
# 57037         UW-04                  Member    Male     1994.0
# 57038        SLU-16                  Member    Male     1987.0
# 57039         BT-04                  Member    Male     1990.0
# 57040        SLU-07                  Member    Male     1987.0
# 57041         WF-01  Short-Term Pass Holder     NaN        NaN
# 57042         WF-01  Short-Term Pass Holder     NaN        NaN
# 57043         BT-03                  Member    Male     1985.0
# 57044        DPD-01                  Member    Male     1990.0
# 57045        SLU-15  Short-Term Pass Holder     NaN        NaN
# 57046         UD-01                  Member    Male     1992.0
# 57047        CBD-05                  Member    Male     1962.0
# 57048        SLU-04                  Member    Male     1987.0
# 57049         CH-08                  Member    Male     1981.0
# 57050        DPD-01  Short-Term Pass Holder     NaN        NaN
# 57051        CBD-03  Short-Term Pass Holder     NaN        NaN
# 57052        SLU-01                  Member    Male     1987.0
# 57053        DPD-01                  Member    Male     1974.0
# 57054        SLU-07                  Member    Male     1987.0
# 57055        SLU-16                  Member    Male     1985.0
# 57056        CBD-13  Short-Term Pass Holder     NaN        NaN
# 57057        SLU-04                  Member    Male     1987.0
# 57058         WF-01                  Member  Female     1953.0
# 57059        SLU-04                  Member  Female     1992.0
# 57060         PS-04                  Member    Male     1976.0
# 57061           NaN                     NaN     NaN        NaN
#
# [57062 rows x 12 columns]

# %% [markdown]
# Check the lenght of the data

# %%
length = len(df)
length
# Out:
# 57062

# %% [markdown]
# Univariate Analysis to determine the time range of data set<br>
# We sort the data frame by `starttime`<br>
# what sorting did was to change the position of records within the data frame, and hence the change in positions disturbed the arrangement of the indexes which were earlier in an ascending order. Hence, considering this, we decided to reset the indexes so that the ordered data frame now has indexes in an ascending order. Finally, we printed the date range that started from the first value of starttime and ended with the last value of stoptime

# %%
df2 = df.sort('starttime')
df2
# Out:
# /home/nbuser/anaconda3_420/lib/python3.5/site-packages/ipykernel/__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
#        trip_id       starttime        stoptime    bikeid  tripduration  \
# 20239    25091   1/1/2015 0:24   1/1/2015 0:48  SEA00325      1403.479
# 20240    25092   1/1/2015 0:37   1/1/2015 0:44  SEA00267       459.469
# 20241    25093   1/1/2015 0:44   1/1/2015 0:48  SEA00124       255.004
# 20259    25131  1/1/2015 10:14  1/1/2015 10:33  SEA00204      1145.254
# 20260    25132  1/1/2015 10:55  1/1/2015 11:03  SEA00391       470.801
# 20261    25133  1/1/2015 10:59  1/1/2015 11:01  SEA00058       136.101
# 20262    25134  1/1/2015 11:09  1/1/2015 11:31  SEA00434      1294.421
# 20263    25135  1/1/2015 11:31  1/1/2015 11:55  SEA00079      1461.638
# 20264    25136  1/1/2015 11:34  1/1/2015 11:45  SEA00107       666.286
# 20265    25137  1/1/2015 11:45  1/1/2015 11:54  SEA00401       524.885
# 20266    25138  1/1/2015 11:47  1/1/2015 16:20  SEA00031     16390.548
# 20267    25139  1/1/2015 11:48  1/1/2015 16:20  SEA00389     16321.122
# 20268    25140  1/1/2015 11:56  1/1/2015 12:11  SEA00147       902.576
# 20269    25142  1/1/2015 12:00  1/1/2015 12:12  SEA00210       699.075
# 20270    25143  1/1/2015 12:13  1/1/2015 12:22  SEA00347       514.110
# 20271    25144  1/1/2015 12:14  1/1/2015 12:22  SEA00326       472.876
# 20272    25145  1/1/2015 12:15  1/1/2015 12:57  SEA00147      2502.464
# 20273    25146  1/1/2015 12:16  1/1/2015 12:57  SEA00200      2449.811
# 20274    25147  1/1/2015 12:16  1/1/2015 12:27  SEA00140       684.994
# 20277    25151  1/1/2015 12:52  1/1/2015 12:59  SEA00390       397.101
#
#       to_station_id                usertype  gender  birthyear
# 20239         CH-15  Short-Term Pass Holder     NaN        NaN
# 20240         CH-08                  Member    Male     1991.0
# 20241        SLU-01                  Member    Male     1987.0
# 20259         PS-04  Short-Term Pass Holder     NaN        NaN
# 20260        CBD-03                  Member    Male     1980.0
# 20261         CH-08                  Member  Female     1986.0
# 20262         EL-05  Short-Term Pass Holder     NaN        NaN
# 20263        SLU-19                  Member    Male     1987.0
# 20264         UW-04  Short-Term Pass Holder     NaN        NaN
# 20265         CH-03                  Member  Female     1987.0
# 20266         UD-02  Short-Term Pass Holder     NaN        NaN
# 20267         UD-02  Short-Term Pass Holder     NaN        NaN
# 20268         EL-03  Short-Term Pass Holder     NaN        NaN
# 20269         EL-03  Short-Term Pass Holder     NaN        NaN
# 20270         FH-04                  Member  Female     1986.0
# 20271         FH-04                  Member    Male     1981.0
# 20272        SLU-07  Short-Term Pass Holder     NaN        NaN
# 20273        SLU-07  Short-Term Pass Holder     NaN        NaN
# 20274        SLU-04                  Member    Male     1981.0
# 20277         CH-02                  Member    Male     1975.0
# 20275         WF-04  Short-Term Pass Holder     NaN        NaN
# 20276         ID-04                  Member  Female     1985.0
# 20278         WF-04  Short-Term Pass Holder     NaN        NaN
# 20279         ID-04  Short-Term Pass Holder     NaN        NaN
# 20280         ID-04  Short-Term Pass Holder     NaN        NaN
# 20281        SLU-15                  Member  Female     1977.0
# 20282        SLU-15                  Member    Male     1974.0
# 20283        SLU-07  Short-Term Pass Holder     NaN        NaN
# 20284         ID-04  Short-Term Pass Holder     NaN        NaN
# 20285        SLU-07  Short-Term Pass Holder     NaN        NaN
# ...             ...                     ...     ...        ...
# 47931        SLU-15                  Member    Male     1969.0
# 47932        CBD-06                  Member    Male     1980.0
# 47933        CBD-06                  Member    Male     1984.0
# 47934        CBD-03                  Member    Male     1976.0
# 47935        CBD-13                  Member    Male     1993.0
# 47936        CBD-06                  Member    Male     1962.0
# 47937        SLU-04                  Member    Male     1986.0
# 47938        DPD-01                  Member    Male     1984.0
# 47939        CBD-05                  Member    Male     1979.0
# 47942        SLU-04                  Member    Male     1987.0
# 47941        SLU-04                  Member    Male     1987.0
# 47940         WF-04                  Member  Female     1982.0
# 47943        SLU-16                  Member  Female     1972.0
# 47944        SLU-02                  Member    Male     1982.0
# 47945        CBD-05  Short-Term Pass Holder     NaN        NaN
# 47946        SLU-18                  Member    Male     1982.0
# 47947        CBD-03                  Member    Male     1981.0
# 47948        SLU-16                  Member    Male     1969.0
# 47949        SLU-04                  Member    Male     1990.0
# 47951         UW-06                  Member    Male     1992.0
# 47950         BT-04                  Member    Male     1987.0
# 47952        CBD-13                  Member    Male     1959.0
# 47953        DPD-01                  Member    Male     1991.0
# 47954        SLU-04                  Member    Male     1982.0
# 47955        SLU-04                  Member    Male     1987.0
# 47956         PS-04                  Member    Male     1988.0
# 47957         BT-04                  Member    Male     1981.0
# 47958        DPD-01                  Member    Male     1990.0
# 21                                 6th Ave S & S King St           CH-07
# 22     Seattle Aquarium / Alaskan Way S & Elliott Bay...           BT-01
# 23                                 6th Ave S & S King St           CH-07
# 24                                 6th Ave S & S King St           CH-07
# 25                                Westlake Ave & 6th Ave           EL-03
# 26                                Westlake Ave & 6th Ave           EL-03
# 27                         PATH / 9th Ave & Westlake Ave          DPD-01
# 28                                 6th Ave S & S King St           CH-08
# 29                         PATH / 9th Ave & Westlake Ave          DPD-01
# ...                                                  ...             ...
# 57032                             Westlake Ave & 6th Ave          CBD-05
# 57033                                2nd Ave & Spring St          SLU-01
# 57034                                2nd Ave & Spring St           BT-01
# 57035                                 7th Ave & Union St           CH-03
# 57036                                  2nd Ave & Pine St           CH-07
# 57037                                2nd Ave & Spring St           CH-15
# 57038                     Republican St & Westlake Ave N           CH-06
# 57039                              9th Ave N & Mercer St           BT-01
# 57040                                1st Ave & Marion St           CH-15
# 57041                     Republican St & Westlake Ave N          SLU-16
# 57042                     Republican St & Westlake Ave N          SLU-16
# 57043  Seattle Aquarium / Alaskan Way S & Elliott Bay...           WF-01
# 57044                                  Pine St & 9th Ave           CH-07
# 57045                            Dexter Ave N & Aloha St           BT-01
# 57046                                1st Ave & Marion St           WF-01
# 57047                             Dexter Ave & Denny Way          CBD-07
# 57048                                 7th Ave & Union St           CH-03
# 57049                                  Pine St & 9th Ave           CH-01
# 57050                     Republican St & Westlake Ave N          CBD-03
# 57051  UW Engineering Library / E Stevens Way NE & Je...           UW-01
# 57052                             6th Ave & Blanchard St          SLU-07
# 57053                                  2nd Ave & Pine St           FH-04
# 57054                              9th Ave N & Mercer St           CH-15
# 57055                     Republican St & Westlake Ave N          SLU-18
# 57056                     Republican St & Westlake Ave N          SLU-16
# 57057  Occidental Park / Occidental Ave S & S Washing...           CH-01
# 57058                             6th Ave & Blanchard St          CBD-06
# 57059                              9th Ave N & Mercer St           BT-04
# 57060                              9th Ave N & Mercer St          SLU-18
# 57061                       E Blaine St & Fairview Ave E          SLU-18
#
#       to_station_id                usertype  gender  birthyear
# 0             CH-15  Short-Term Pass Holder     NaN        NaN
# 1             CH-08                  Member    Male     1991.0
# 2            SLU-01                  Member    Male     1987.0
# 3             PS-04  Short-Term Pass Holder     NaN        NaN
# 4            CBD-03                  Member    Male     1980.0
# 5             CH-08                  Member  Female     1986.0
# 6             EL-05  Short-Term Pass Holder     NaN        NaN
# 7            SLU-19                  Member    Male     1987.0
# 8             UW-04  Short-Term Pass Holder     NaN        NaN
# 9             CH-03                  Member  Female     1987.0
# 10            UD-02  Short-Term Pass Holder     NaN        NaN
# 11            UD-02  Short-Term Pass Holder     NaN        NaN
# 12            EL-03  Short-Term Pass Holder     NaN        NaN
# 13            EL-03  Short-Term Pass Holder     NaN        NaN
# 14            FH-04                  Member  Female     1986.0
# 15            FH-04                  Member    Male     1981.0
# 16           SLU-07  Short-Term Pass Holder     NaN        NaN
# 17           SLU-07  Short-Term Pass Holder     NaN        NaN
# 18           SLU-04                  Member    Male     1981.0
# 19            CH-02                  Member    Male     1975.0
# 20            WF-04  Short-Term Pass Holder     NaN        NaN
# 21            ID-04                  Member  Female     1985.0
# 22            WF-04  Short-Term Pass Holder     NaN        NaN
# 23            ID-04  Short-Term Pass Holder     NaN        NaN
# 24            ID-04  Short-Term Pass Holder     NaN        NaN
# 25           SLU-15                  Member  Female     1977.0
# 26           SLU-15                  Member    Male     1974.0
# 27           SLU-07  Short-Term Pass Holder     NaN        NaN
# 28            ID-04  Short-Term Pass Holder     NaN        NaN
# 29           SLU-07  Short-Term Pass Holder     NaN        NaN
# ...             ...                     ...     ...        ...
# 57032        SLU-15                  Member    Male     1969.0
# 57033        CBD-06                  Member    Male     1980.0
# 57034        CBD-06                  Member    Male     1984.0
# 57035        CBD-03                  Member    Male     1976.0
# 57036        CBD-13                  Member    Male     1993.0
# 57037        CBD-06                  Member    Male     1962.0
# 57038        SLU-04                  Member    Male     1986.0
# 57039        DPD-01                  Member    Male     1984.0
# 57040        CBD-05                  Member    Male     1979.0
# 57041        SLU-04                  Member    Male     1987.0
# 57042        SLU-04                  Member    Male     1987.0
# 57043         WF-04                  Member  Female     1982.0
# 57044        SLU-16                  Member  Female     1972.0
# 57045        SLU-02                  Member    Male     1982.0
# 57046        CBD-05  Short-Term Pass Holder     NaN        NaN
# 57047        SLU-18                  Member    Male     1982.0
# 57048        CBD-03                  Member    Male     1981.0
# 57049        SLU-16                  Member    Male     1969.0
# 57050        SLU-04                  Member    Male     1990.0
# 57051         UW-06                  Member    Male     1992.0
# 57052         BT-04                  Member    Male     1987.0
# 57053        CBD-13                  Member    Male     1959.0
# 57054        DPD-01                  Member    Male     1991.0
# 57055        SLU-04                  Member    Male     1982.0
# 57056        SLU-04                  Member    Male     1987.0
# 57057         PS-04                  Member    Male     1988.0
# 57058         BT-04                  Member    Male     1981.0
# 57059        DPD-01                  Member    Male     1990.0
# 57060        DPD-01                  Member    Male     1981.0
# 57061         EL-03                  Member    Male     1980.0
#
# [57062 rows x 13 columns]

# %%
print("Data Range is from: ",'[',df2.loc[1,'starttime'],']',' to ','[',df2.loc[len(df2)-1,'stoptime'],']')
# Out:
# Data Range is from:  [ 1/1/2015 0:37 ]  to  [ 4/9/2015 10:09 ]

# %% [markdown]
# There are two insights. One is that the data ranges from October 2014 up till September 2016 (i.e., three years of data). Moreover, it seems like the cycle sharing service is usually operational beyond the standard 9 to 5 business hours.

# %% [markdown]
# new users would be short-term pass holders however once they try out the service and become satisfied would ultimately avail the membership to receive the perks and benefits offered<br>
# plot a bar graph of trip frequencies by user type

# %% [markdown]
# groupby groups the data by a given field, that is, usertype, in the current situation<br>
# size counts trips falling within each of the grouped usertypes

# %%
fre_usr_stat = df2.groupby('usertype').size()
fre_usr_stat
# Out:
# usertype
# Member                    38336
# Short-Term Pass Holder    18725
# dtype: int64

# %%
fre_usr_stat.plot.barh(figsize=(5,5),title='FREQUENCY-USER-GRAPH')

# %% [markdown]
# You may want know more about her target customers to whom to company’s marketing message will be targetted to<br>
# Find out the gender and age groups that are most likely to ride a cycle or the ones that are more prone to avail the service.<br>
# Fing out the distribution of gender and birth years

# %%
gender_stat = df2.groupby('gender').size()
gender_stat
# Out:
# gender
# Female     7880
# Male      29877
# Other       579
# dtype: int64

# %%
gender_stat.plot.barh(figsize=(10,5),title='GENDER GRAPH')

# %%
birth_stat = df2.groupby('birthyear').size()
birth_stat
# Out:
# birthyear
# 1936.0       1
# 1939.0       1
# 1942.0       2
# 1943.0      10
# 1944.0       1
# 1945.0      59
# 1946.0      31
# 1947.0      80
# 1948.0      30
# 1949.0      86
# 1950.0     337
# 1951.0     132
# 1952.0      68
# 1953.0     113
# 1954.0     112
# 1955.0     260
# 1956.0     177
# 1957.0     107
# 1958.0     112
# 1959.0     328
# 1960.0     218
# 1961.0     350
# 1962.0     826
# 1963.0     295
# 1964.0     442
# 1965.0     710
# 1966.0     453
# 1967.0     757
# 1968.0     513
# 1969.0     517
# 1970.0     211
# 1971.0     678
# 1972.0     903
# 1973.0     423
# 1974.0     699
# 1975.0     883
# 1976.0     672
# 1977.0    1265
# 1978.0     745
# 1979.0     787
# 1980.0     879
# 1981.0    2312
# 1982.0    2023
# 1983.0    1583
# 1984.0    1870
# 1985.0    2104
# 1986.0    1688
# 1987.0    4685
# 1988.0    1675
# 1989.0    1088
# 1990.0    1459
# 1991.0    1360
# 1992.0     637
# 1993.0     352
# 1994.0     190
# 1995.0       9
# 1996.0      22
# 1998.0       4
# 1999.0       2
# dtype: int64

# %%
birth_stat.plot.bar(figsize=(15,5),title='BIRTH-YEAR-GRAPH')

# %% [markdown]
# millenials are supposed to make a conscious decision, a decision they will remain loyal to for a long period. Hence we mat assume that the most millennials would be members rather than short-term pass holders. Based on data below, it appeared to be valid, and we can make sure that the brand engaged millennials as part of the marketing plan.

# %%
mill_stat = df2.groupby('usertype')['birthyear'].size()
mill_stat
# Out:
# usertype
# Member                    38336
# Short-Term Pass Holder    18725
# dtype: int64

# %%
mill_stat.plot.barh(figsize=(10,5))

# %% [markdown]
# ### Multivariate Analysis
# Multivariate analysis refers to incorporation of multiple exploratory variables to understand the behavior of a response variable. This seems to be the most feasible and realistic approach considering the fact that entities within this world are usually interconnected. Thus the variability in response variable might be affected by the variability in the interconnected exploratory variables<br>

# %% [markdown]
# Who completed more trips male or female. Draw a stacked bar graph (i.e., a bar graph for birth year, but each bar having two colors, one for each gender)

# %% [markdown]
# We at first transformed the data frame by **unstacking**, that is, splitting, the gender column into three columns, that is, Male, Female, and Other. This meant that for each of the birth years we had the trip count for all three gender types. Finally, a stacked bar graph was created by using this transformed data frame.

# %%
birth_gen_stat = df2.groupby(['birthyear', 'gender'])['birthyear'].count()
birth_gen_stat = birth_gen_stat.unstack('gender')
birth_gen_stat = birth_gen_stat.fillna(0)
birth_gen_stat
# Out:
# gender     Female    Male  Other
# birthyear
# 1936.0        0.0     1.0    0.0
# 1939.0        0.0     1.0    0.0
# 1942.0        0.0     2.0    0.0
# 1943.0        0.0    10.0    0.0
# 1944.0        0.0     1.0    0.0
# 1945.0        0.0    59.0    0.0
# 1946.0       20.0    11.0    0.0
# 1947.0       70.0    10.0    0.0
# 1948.0        3.0    27.0    0.0
# 1949.0       38.0    48.0    0.0
# 1950.0      221.0   116.0    0.0
# 1951.0       89.0    43.0    0.0
# 1952.0       18.0    46.0    4.0
# 1953.0       15.0    98.0    0.0
# 1954.0       53.0    59.0    0.0
# 1955.0       25.0   235.0    0.0
# 1956.0        9.0   167.0    1.0
# 1957.0       16.0    42.0   49.0
# 1958.0       24.0    88.0    0.0
# 1959.0      121.0   207.0    0.0
# 1960.0       61.0   157.0    0.0
# 1961.0       84.0   266.0    0.0
# 1962.0       59.0   767.0    0.0
# 1963.0      169.0   126.0    0.0
# 1964.0      266.0   176.0    0.0
# 1965.0       98.0   612.0    0.0
# 1966.0      183.0   254.0   16.0
# 1967.0       72.0   636.0   49.0
# 1968.0       12.0   501.0    0.0
# 1969.0       32.0   485.0    0.0
# 1970.0       65.0   146.0    0.0
# 1971.0      201.0   477.0    0.0
# 1972.0      193.0   710.0    0.0
# 1973.0      139.0   284.0    0.0
# 1974.0      101.0   598.0    0.0
# 1975.0       66.0   817.0    0.0
# 1976.0      114.0   558.0    0.0
# 1977.0      353.0   879.0   33.0
# 1978.0      158.0   482.0  105.0
# 1979.0      178.0   609.0    0.0
# 1980.0      190.0   674.0   15.0
# 1981.0      219.0  2067.0   26.0
# 1982.0      396.0  1626.0    1.0
# 1983.0      320.0  1263.0    0.0
# 1984.0      617.0  1253.0    0.0
# 1985.0      374.0  1725.0    5.0
# 1986.0      437.0  1240.0   11.0
# 1987.0      433.0  4029.0  223.0
# 1988.0      327.0  1348.0    0.0
# 1989.0      203.0   885.0    0.0
# 1990.0      243.0  1216.0    0.0
# 1991.0      563.0   797.0    0.0
# 1992.0      109.0   487.0   41.0
# 1993.0        6.0   346.0    0.0
# 1994.0      104.0    86.0    0.0
# 1995.0        2.0     7.0    0.0
# 1996.0        6.0    16.0    0.0
# 1998.0        3.0     1.0    0.0
# 1999.0        2.0     0.0    0.0

# %%
birth_gen_stat[['Male','Female','Other']].plot.bar(figsize=(15,5),stacked=True,title='BIRTH-YEAR-GENDER-GRAPH')

# %% [markdown]
# It seemed as if males were dominating the distribution. It made sense as well. No? Well, it did; as seen earlier, that majority of the trips were availed by males, hence this skewed the distribution in favor of males. However, subscribers born in 1947 were all females. Moreover, those born in 1964 and 1994 were dominated by females as wel

# %% [markdown]
# what the distribution of user type was for the other age generations. Is it that the majority of people in the other age generations were short-term pass holders?

# %%
birth_usr_stat = df2.groupby(['birthyear', 'usertype'])['birthyear'].count()
birth_usr_stat = birth_usr_stat.unstack('usertype')
birth_usr_stat = birth_usr_stat.fillna(0)
birth_usr_stat
# Out:
# usertype   Member
# birthyear
# 1936.0        1.0
# 1939.0        1.0
# 1942.0        2.0
# 1943.0       10.0
# 1944.0        1.0
# 1945.0       59.0
# 1946.0       31.0
# 1947.0       80.0
# 1948.0       30.0
# 1949.0       86.0
# 1950.0      337.0
# 1951.0      132.0
# 1952.0       68.0
# 1953.0      113.0
# 1954.0      112.0
# 1955.0      260.0
# 1956.0      177.0
# 1957.0      107.0
# 1958.0      112.0
# 1959.0      328.0
# 1960.0      218.0
# 1961.0      350.0
# 1962.0      826.0
# 1963.0      295.0
# 1964.0      442.0
# 1965.0      710.0
# 1966.0      453.0
# 1967.0      757.0
# 1968.0      513.0
# 1969.0      517.0
# 1970.0      211.0
# 1971.0      678.0
# 1972.0      903.0
# 1973.0      423.0
# 1974.0      699.0
# 1975.0      883.0
# 1976.0      672.0
# 1977.0     1265.0
# 1978.0      745.0
# 1979.0      787.0
# 1980.0      879.0
# 1981.0     2312.0
# 1982.0     2023.0
# 1983.0     1583.0
# 1984.0     1870.0
# 1985.0     2104.0
# 1986.0     1688.0
# 1987.0     4685.0
# 1988.0     1675.0
# 1989.0     1088.0
# 1990.0     1459.0
# 1991.0     1360.0
# 1992.0      637.0
# 1993.0      352.0
# 1994.0      190.0
# 1995.0        9.0
# 1996.0       22.0
# 1998.0        4.0
# 1999.0        2.0

# %%
birth_usr_stat[['Member']].plot.bar(figsize=(15,5),title='BIRTH-YEAR-USER-GRAPH')

# %% [markdown]
# The graph shows the distribution of only one user type and not two (i.e., membership and short-term pass holders)? Does this mean that birth year information was only present for only one user type?
# Validation If We Don’t Have Birth Year Available for Short-Term Pass Holders

# %%
df2[df2['usertype'] == ('Short-Term Pass Holder')]['birthyear'].isnull().values.all()
# Out:
# True

# %% [markdown]
# We first sliced the data frame to consider only short-term pass holders. Then we went forward to find out if all the values in birth year are missing (i.e., null) for this slice. Members have to provide details like birth year when applying for the membership, something which is not a prerequisite for short-term pass holders. WE decided to test this deduction by checking if gender is available for short-term pass holders or not

# %%
df2[df2['usertype'] == ('Short-Term Pass Holder')]['gender'].isnull().values.all()
# Out:
# True

# %% [markdown]
# how the frequency of trips vary across date and time (i.e., a time series analysis). Trip start time is given with the data, but to make a time series plot, we had to transform the date from string to date time format. Split the datetime into date components (i.e., year, month, day, and hour )

# %% [markdown]
# At first we converted start time column of the dataframe into a list. Next we converted the string dates into python datetime objects. We then converted the list into a series object and converted the dates from datetime object to pandas date object. The time components of year, month, day and hour were derived from the list with the datetime objects.

# %%
List_ = list(df2['starttime'])

List_ = [datetime.datetime.strptime(x, "%m/%d/%Y %H:%M") for x in List_]
df2['starttime_mod'] = pd.Series(List_,index=df2.index)
df2['starttime_date'] = pd.Series([x.date() for x in List_],index=df2.index)
df2['starttime_year'] = pd.Series([x.year for x in List_],index=df2.index)
df2['starttime_month'] = pd.Series([x.month for x in List_],index=df2.index)
df2['starttime_day'] = pd.Series([x.day for x in List_],index=df2.index)
df2['starttime_hour'] = pd.Series([x.hour for x in List_],index=df2.index)

# %%
df2.groupby('starttime_date')['tripduration'].mean().plot.bar(title = 'Distribution of Trip duration by date', figsize = (20,5))

# %% [markdown]
# Determining the measures of centers using the statistics package will require us to transform the input data structure to a list type.

# %%
trip_duration = list(df2['tripduration'])
station_from = list(df2['from_station_name'])
print ('Mean of trip duration: %f'%statistics.mean(trip_duration))
print ('Median of trip duration: %f'%statistics.median(trip_duration))
print ('Mode of station originating from: %s'%statistics.mode(station_from))
# Out:
# Mean of trip duration: nan
# Median of trip duration: 596.196500
# Mode of station originating from: REI / Yale Ave N & John St

# %% [markdown]
# The output revealed that most trips originated from Pier 69/Alaskan Way & Clay St station. Hence this was the ideal location for running promotional campaigns targeted to existing customers. Moreover, the output showed the mean to be greater than that of the mean.<br>
# why the average (i.e., mean) is greater than the central value (i.e., median).<br>
# this might be either due to some extreme values after the median or due to the majority of values lying after the median.<br> plot a distribution of the trip durations in order to determine which premise holds true .

# %%
df2['tripduration'].plot.hist(bins=100,title='Frequency distribution of Trip duration',figsize=(5,5))

# %% [markdown]
# The distribution has only one peak (i.e., mode). The distribution is not symmetric and has majority of values toward the right-hand side of the mode. These extreme values toward the right are negligible in quantity, but their extreme nature tends to pull the mean toward themselves. Thus the reason why the mean is greater than the median<br>
# The distribution is referred to as a **normal distribution.**

# %% [markdown]
# Find out whether outliers exist within our dataset—more precisely in the tripduration feature. For that first create a box plot by writing code to see the outliers visually and then checked the same by applying the interval calculation method

# %%
box = df2.boxplot(column=['tripduration'])

# %% [markdown]
# See a huge number of outliers in trip duration from the box plot. She asked Eric if he could determine the proportion of trip duration values which are outliers. She wanted to know if outliers are a tiny or majority portion of the dataset

# %%
q75, q25 = np.percentile(trip_duration, [75 ,25])
iqr = q75 - q25
print ('Proportion of values as outlier: %f percent'%(
(len(df2) - len([x for x in trip_duration if q75+(1.5*iqr) >=x>= q25-(1.5*iqr)]))*100/float(len(df2))))
# Out:
# Proportion of values as outlier: 100.000000 percent

# %% [markdown]
# Q3 refers to the 75th percentile and Q1 refers to the 25th percentile. Hence we use the numpy.percentile() method to determine the values for Q1 and Q3. Next we compute the IQR by subtracting both of them. Then we determine the subset of values by applying the interval. We then used the formula to get the number of outliers.
# In our code, len(data) determines Length of all values and Length of all non outliers values is determined by `len([x for x in trip_duration if q75+(1.5*iqr) >=x>= q25-(1.5*iqr)]))`

# %% [markdown]
# Considering the time series nature of the dataset, removing these outliers wouldn’t be an option. The only option we could rely on was to apply transformation to these outliers to negate their extreme nature. However, we are interested in observing the mean of the non-outlier values of trip duration. This we can compare with the mean of all values calculated earlier

# %%
mean_trip = np.mean([x for x in trip_duration if q75+(1.5*iqr) >=x>= q25-(1.5*iqr)])
upper_whisker = q75+(1.5*iqr)
print('Mean of trip duration: %f'%mean_trip)
# Out:
# Mean of trip duration: nan
# /home/nbuser/anaconda3_420/lib/python3.5/site-packages/numpy/core/fromnumeric.py:3257: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/nbuser/anaconda3_420/lib/python3.5/site-packages/numpy/core/_methods.py:161: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %% [markdown]
# The mean of non-outlier trip duration values in (i.e., approximately 712) is considerably lower than that calculated in the presence of outliers in Listing 1-15 (i.e., approximately 1,203). This best describes the notion that mean is highly affected by the presence of outliers in the dataset.

# %% [markdown]
# upper_whisker is the maximum value of the right (i.e., positive) whisker i.e. boundary uptill which all values are valid and any value greater than that is considered as an outlier

# %% [markdown]
# WE are interested to see the outcome statistics once the outliers were transformed into valid value sets. Hence we decided to start with a simple outlier transformation to the mean of valid values

# %%
def transform_tripduration(x):

    if x > upper_whisker:
        return mean_trip_duration
    return x

df2['tripduration_mean'] = df2['tripduration'].apply(lambda x: transform_tripduration(x))

print(df2['tripduration_mean'])

df2['tripduration_mean'].plot.hist(bins=100, title='Frequency distribution of mean transformed Trip duration')
plt.show()
# Out:
# 0         1403.479
# 1          459.469
# 2          255.004
# 3         1145.254
# 4          470.801
# 5          136.101
# 6         1294.421
# 7         1461.638
# 8          666.286
# 9          524.885
# 10       16390.548
# 11       16321.122
# 12         902.576
# 13         699.075
# 14         514.110
# 15         472.876
# 16        2502.464
# 17        2449.811
# 18         684.994
# 19         397.101
# 20         740.454
# 21        1463.476
# 22         682.798
# 23        1219.227
# 24        1132.444
# 25        1101.863
# 26        1057.551
# 27        1166.184
# 28         801.236
# 29        1111.246
#            ...
# 57032      465.089
# 57033      530.809
# 57034      410.825
# 57035      515.103
# 57036      566.387
# 57037      835.321
# 57038      385.658
# 57039      411.887
# 57040      667.543
# 57041      396.963
# 57042      394.039
# 57043      338.995
# 57044      430.216
# 57045     4741.051
# 57046      994.094
# 57047      587.449
# 57048      390.669
# 57049      175.865
# 57050      631.674
# 57051       98.209
# 57052      162.906
# 57053      721.610
# 57054      566.732
# 57055      300.497
# 57056      311.038
# 57057      697.563
# 57058      532.814
# 57059      269.124
# 57060      242.662
# 57061      764.461
# Name: tripduration_mean, dtype: float64

# %% [markdown]
# We initialized a function by the name of transform_tripduration . The function will check if a trip duration value is greater than the upper whisker boundary value, and if that is the case it will replace it with the mean. Next we add tripduration_mean as a new column to the data frame. We did so by custom modifying the already existing tripduration column by applying the transform_tripduration function.

# %% [markdown]
# the skewness has now decreased to a great extent after the transformation. Moreover, the majority of the observations have a tripduration of 712 primarily because all values greater than the upper whisker boundary are now converted into the mean of the non-outlier values calculated. We are now interested in understanding how the center of measures appear for this transformed distribution. Hence we came up with the code

# %%
print('Mean of trip duration: %f'%df2['tripduration_mean'].mean())
print('Standard deviation of trip duration: %f'%df2['tripduration_mean'].std())
print('Median of trip duration: %f'%df2['tripduration_mean'].median())
# Out:
# Mean of trip duration: 1101.187491
# Standard deviation of trip duration: 1953.504561
# Median of trip duration: 601.272000

# %% [markdown]
# We were expecting the mean to appear the same as previous because of the mean transformation of the outlier values. WE knew that the hike at 711.7 is the mode, which meant that after the transformation the mean is the same as that of the mode. The thing that surprised the most was that the median is approaching the mean, which means that the positive skewness we saw in is not that strong.

# %% [markdown]
# Pearson R correlation into practice and decided to make a scatter plot between the two quantities for them to see the relationship visually.

# %%
pd.set_option('display.width', 100)
pd.set_option('precision', 3)

df2['age'] = df2['starttime_year'] - df2['birthyear']

correlations = df2[['tripduration','age']].corr(method='pearson')
print(correlations)
# Out:
#               tripduration    age
# tripduration         1.000  0.047
# age                  0.047  1.000

# %%
df2 = df2.dropna()
sns.pairplot(df2, vars=['age', 'tripduration'], kind='reg')
plt.show()
# Out:
# /home/nbuser/anaconda3_420/lib/python3.5/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
for cat in ['gender','usertype']:
    print ('Category: %s\n'%cat)
    groupby_category = df2.groupby(['starttime_date', cat])['starttime_date'].count().unstack(cat)
    groupby_category = groupby_category.dropna()
    category_names = list(groupby_category.columns)

    for comb in [(category_names[i],category_names[j]) for i in range(len(category_names)) for j in range(i+1, len(category_names))]:

        print ('%s %s'%(comb[0], comb[1]))
        t_statistics = stats.ttest_ind(list(groupby_category[comb[0]]), list(groupby_category[comb[1]]))
        print ('Statistic: %f, P value: %f'%(t_statistics.statistic, t_statistics.pvalue))

        print ('\n')
# Out:
# Category: gender
#
# Female Male
# Statistic: -23.492922, P value: 0.000000
#
#
# Female Other
# Statistic: 29.118388, P value: 0.000000
#
#
# Male Other
# Statistic: 32.563926, P value: 0.000000
#
#
# Category: usertype

# %%
"""SUMMERY"""
# Out:
# 'SUMMERY'

# %%
"""
At first we added some liberaries. Next we added the data file. Check its length and sort it by a column starttime and after it we print the range of 
data. 

After it we print the number of members and short-term pass holders and plot their graph.

We find the gender of all customer which is male, female or others. And then we plot a graph showing th gender of patients.

Next we get the birthyear of the costomer and plot the graph for that.

Aftr it we did some analysis and form graphs according to user type, birthyear and gender , birth year.

Next we converted the string dates into python datetime objects. We then converted the list into a series object and converted the dates from datetime 
object to pandas date object. The time components of year, month, day and hour were derived from the list with the datetime objects.

Next we did some statistics on the trip duration  column from the main data. And made some graphs to easily compare the data.

Next we determine the proportion of trip duration values which are outliers.

Next we see the outcome statistics once the outliers were transformed into valid value sets. Hence we decided to start with a simple outlier 
transformation to the mean of valid values

We are now interested in understanding how the center of measures appear for this transformed distribution. Hence we came up with the code to do so.

Next we make Pearson R correlation into practice and decided to make a scatter plot between the two quantities for them to see the relationship visually.

"""
# Out:
# '\nAt first we added some liberaries. Next we added the data file. Check its length and sort it by a column starttime and after it we print the range of \ndata. \n\nAfter it we print the number of members and short-term pass holders and plot their graph.\n\nWe find the gender of all customer which is male, female or others. And then we plot a graph showing th gender of patients.\n\nNext we get the birthyear of the costomer and plot the graph for that.\n\nAftr it we did some analysis and form graphs according to user type, birthyear and gender , birth year.\n\nNext we converted the string dates into python datetime objects. We then converted the list into a series object and converted the dates from datetime \nobject to pandas date object. The time components of year, month, day and hour were derived from the list with the datetime objects.\n\nNext we did some statistics on the trip duration  column from the main data. And made some graphs to easily compare the data.\n\nNext we determine the proportion of trip duration values which are outliers.\n\nNext we see the outcome statistics once the outliers were transformed into valid value sets. Hence we decided to start with a simple outlier \ntransformation to the mean of valid values\n\nWe are now interested in understanding how the center of measures appear for this transformed distribution. Hence we came up with the code to do so.\n\nNext we make Pearson R correlation into practice and decided to make a scatter plot between the two quantities for them to see the relationship visually.\n\n'

# %% [markdown]
# """
#
# So now after analyzing the whole Project we can say that this project should be launched near
# ""REI / Yale Ave N & John St""
#
# """

# %%
"""ありがとう"""
# Out:
# 'ありがとう'
